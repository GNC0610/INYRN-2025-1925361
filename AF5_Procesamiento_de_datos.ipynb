# %% [markdown]
# <a href="https://colab.research.google.com/github/GNC0610/INYRN-2025-1925361/blob/main/AF5_Procesamiento_de_datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Actividad 5: Procesamiento de conjuntos de datos en Python**

# %% [markdown]
# *   1799047 Eva Melissa Aguilar Frayre N4
# *   2045431 Carlos Eduardo Reyes Rodríguez N4
# *   2054276 Megan Johana Hernández Jasso N4
# *   2049765 Daena victoria Santiago del Ángel N4
# *   1925361 Guillermo Niño Camacho N4

# %% [markdown]
# Ejercicio 1.- Análisis y normalización de datos de sensores en un robot móvil

# %%
# Cargar librerias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Fuente https://github.com/dilp90/InteligenciaArtificial_y_RedesNeuronales_UANL_FIME/blob/main/MachineLearning/Datasets/robot_sensors.csv
# Cargar datos desde un archivo CSV
df=pd.read_csv('/content/robot_sensors.csv')

# %%
## Mostrar las primeras 10 lineas del dataset
print(df.head(10))
# Out:
#    Tiempo (s)  Distancia (cm)  Velocidad (cm/s)  Temperatura (°C)
# 0           0       43.708611          9.256646         23.925585
# 1           1       95.564288         27.095047         23.704682
# 2           2       75.879455         43.647292         33.593819
# 3           3       63.879264         36.611244         23.743193
# 4           4       24.041678         40.328057         24.079246
# 5           5       24.039507         32.939168         31.390974
# 6           6       15.227525         34.613828         26.746098
# 7           7       87.955853         42.459783         31.650658
# 8           8       64.100351         12.483400         20.980492
# 9           9       73.726532         24.471248         27.313568

# %%
# Eliminar filas con valores nulos
df = df.dropna()

# %%
# Filtrar valores atipicos - velocidades negativas
df = df[df['Velocidad (cm/s)'] >= 0]
# Filtrar valores atipicos -  distancia mayores a 30 cm
df_DistanciaM=df[df['Distancia (cm)']>30]
# Filtrar valores atipicos - velocidades menores a 5
df_velocidad= df[df['Velocidad (cm/s)']>5]

# %%
# Normalizar  los datos con con Min-Max Scaling
columnas=['Tiempo (s)','Distancia (cm)','Velocidad (cm/s)','Temperatura (°C)']
df_normalizado=df.copy()
for columna in columnas:
    df_normalizado[columna]=(df_normalizado[columna]-df_normalizado[columna].min())/(df_normalizado[columna].max()-df_normalizado[columna].min())

# %%
# Visualizar los datos normalizados usando matplotlib
for columna in columnas:
    plt.figure(figsize=(10,5))
    plt.plot(df_normalizado['Tiempo (s)'],df_normalizado[columna],label=columna)
    plt.title('Distribucion de los datos')
    plt.xlabel('Valores Normalizados')
    plt.ylabel('Frecuencia de Aparicion')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
# Visualizar los datos normalizados usando matplotlib

for col in columnas:
    plt.plot(df_normalizado['Tiempo (s)'], df_normalizado[col], label=col)

plt.title('Datos Normalizados del Robot')
plt.xlabel('Tiempo (s)')
plt.ylabel('Valores Normalizados')
plt.legend()
plt.grid(True)
plt.show()
